# %% [markdown]
# # Content based recommendation

# %%
# Base Data Science snippet
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tqdm import tqdm_notebook

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("../")

# %% [markdown]
# # Load data

# %%
# !ls ../data/ml-latest-small
# Out:
# links.csv
# movies.csv
# ratings.csv
# README.txt
# tags.csv

# %%
from movierec.movielens import Movies

# %%
movies = Movies()

# %%
movies.train_KNN()

# %%
movies
# Out:
#       movieId                                              title   imdbId  \
# 0           1                                   Toy Story (1995)   114709
# 1           2                                     Jumanji (1995)   113497
# 2           3                            Grumpier Old Men (1995)   113228
# 3           4                           Waiting to Exhale (1995)   114885
# 4           5                 Father of the Bride Part II (1995)   113041
# 5           6                                        Heat (1995)   113277
# 6           7                                     Sabrina (1995)   114319
# 7           8                                Tom and Huck (1995)   112302
# 8           9                                Sudden Death (1995)   114576
# 9          10                                   GoldenEye (1995)   113189
# 10         11                     American President, The (1995)   112346
# 11         12                 Dracula: Dead and Loving It (1995)   112896
# ...

# %%
data = movies.recommend(imdb_id = "114709") # Toy Story
data
# Out:
#       movieId                                           title  imdbId
# 0           1                                Toy Story (1995)  114709
# 2355     3114                              Toy Story 2 (1999)  120363
# 2809     3754  Adventures of Rocky and Bullwinkle, The (2000)  131704
# 1706     2294                                     Antz (1998)  120587
# 3568     4886                           Monsters, Inc. (2001)  198781
# 3000     4016                Emperor's New Groove, The (2000)  120917

# %%
data = movies.recommend(imdb_id = "112641") # Casino
data
# Out:
#      movieId                                              title  imdbId
# 251      290                          Once Were Warriors (1994)  110729
# 245      283                            New Jersey Drive (1995)  113967
# 29        30  Shanghai Triad (Yao a yao yao dao waipo qiao) ...  115012
# 659      858                              Godfather, The (1972)   68646
# 375      431                               Carlito's Way (1993)  106519
