# %% [markdown]
# # Working on IMDB images

# %%
# Base Data Science snippet
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tqdm import tqdm_notebook

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("../")

# %% [markdown]
# # Downloading images

# %%
# !ls ../data
# Out:
# imdb_images
# ml-latest-small
# README.md

# %%
# !ls ../data/ml-latest-small
# Out:
# links.csv
# movies.csv
# ratings.csv
# README.txt
# tags.csv

# %%
data = pd.read_csv("../data/ml-latest-small/links.csv")
imdb_ids = data["imdbId"].unique().tolist()

# %%
from movierec.imdb import IMDBScrapper,scrapping

# %%
scrapper = IMDBScrapper()

# %%
scrapper.get_movie_poster(imdb_ids[0],save_to = "../data/imdb_images")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=182x268 at 0x20F511FFEB8>

# %%
scrapper.get_movie_posters(imdb_ids,save_to = "../data/imdb_images")
# Out:
# ...
# [75314,
#  61395,
#  58450,
#  76759,
#  59170,
#  74102,
#  83658,
#  99785,
#  99653,
#  99348,
#  96895,
#  29583,
#  32910,
#  65214,
#  82509,
#  70506,
#  65421,
#  48473,
#  52572,
#  62711,
#  58898,
#  95776,
#  118114,
#  57012,
#  70820,
#  63715,
#  61495,
#  53459,
#  68646,
#  35896,
#  32904,
#  45152,
#  43278,
#  50419,
#  54698,
#  52357,
#  47396,
#  25316,
#  36855,
#  25164,
#  53125,
#  53604,
#  53291,
#  56923,
#  34583,
#  33870,
#  58385,
#  47437,
#  46250,
#  31580,
#  37059,
#  32138,
#  31381,
#  84370,
#  43014,
#  33467,
#  62622,
#  42192,
#  32143,
#  32976,
#  32484,
#  38787,
#  38109,
#  50105,
#  48728,
#  42451,
#  45537,
#  31725,
#  50658,
#  51658,
#  29843,
#  32762,
#  37008,
#  39420,
#  29162,
#  27125,
#  35446,
#  28010,
#  49261,
#  48028,
#  25878,
#  32599,
#  48960,
#  38650,
#  31679,
#  29947,
#  34012,
#  25586,
#  27893,
#  41509,
#  26029,
#  63350,
#  43265,
#  46414,
#  51459,
#  33891,
#  22879,
#  48491,
#  72653,
# ...
